# %% [markdown]
# # Métodos pictóricos y tabulares en la Estadística Descriptiva
#
# ## 1. Gráficos de tallo y hojas

# %%
import stemgraphic
  
data = [16, 25, 47, 56, 23, 45, 19, 55, 44, 27, 12, 34, 54, 87, 1, 23, 4, 3]
  
# calling stem_graphic with required parameters,data and scale
stemgraphic.stem_graphic(data, scale = 10)
# Out:
# (<Figure size 540x216 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## 2. Gráficos de puntos

# %%
import numpy as np
import matplotlib.pyplot as plt

#Grafica X vs Y
# crear datos aleatorios
N = 50
x = np.random.rand(N)
y = np.random.rand(N)

plt.scatter(x, y)
plt.title("Scatter plot Simple");

# %%
import numpy as np
import matplotlib.pyplot as plt

# se creara otra variable que se representara con colores
colors = np.random.rand(N) # usar colores aleatorios

# se creara otra variable que se representara con el area de los puntos
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radio

plt.scatter(x, y, s=area, c=colors, alpha=0.4) # el atributo alpha es para la transparencia
plt.title("Scatter plot de representacion de 4 variables");

# %% [markdown]
# ## 3. Histogramas
#
# ### Extraer dataset desde una tabla en pdf y convertir a dataframe

# %%
from tabula import read_pdf
import pandas as pd
import matplotlib.pyplot as plt

#Extraer tabla de un pdf: 
#data = read_pdf("Probabilidad y Estadistica para Ingenieria y Ciencias - Jay Devore - Septima Edicion.pdf", pages="32")
df = pd.read_csv('datasets/muestras_juegos.csv')
plt.hist(df['Frecuencia relativa'], 15, color="red", ec="white")
plt.title("Distribución de frecuencias")
# Out:
# Text(0.5, 1.0, 'Distribución de frecuencias')
